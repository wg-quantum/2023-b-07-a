# %% [markdown]
# # QFL Sample#1-2 qFedAvg

# %% [markdown]
# References:
# - [Paper](https://arxiv.org/abs/2209.00768)
# - [Github](https://github.com/haimengzhao/quantum-fed-infer/blob/main/qFedAvg.ipynb)

# %%
# !git clone https://github.com/haimengzhao/quantum-fed-infer.git
# Out:
# Cloning into 'quantum-fed-infer'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 134 (delta 58), reused 92 (delta 25), pack-reused 0
# Receiving objects: 100% (134/134), 2.08 MiB | 9.23 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
# !ls
# Out:
# PQC-QFL-Model  quantum-fed-infer

# %%
import os
path = '/home/wsuser/work/quantum-fed-infer'

#作業ディレクトリをpathに移動する
os.chdir(path)

#作業ディレクトリ直下のファイルを確認
# !ls
# Out:
# centralized.ipynb  plot.ipynb	      qFedAvg.py	 qFedInf.py
# centralized.py	   qFedAvg.ipynb      qFedInf.ipynb	 README.md
# LICENSE		   qFedAvg_noniid.py  qFedInf_noniid.py

# %%
# !pip install tensorcircuit
# Out:
# Collecting tensorcircuit
#   Downloading tensorcircuit-0.11.0-py3-none-any.whl (329 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.4/329.4 kB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from tensorcircuit) (2.8.4)
# Requirement already satisfied: scipy in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from tensorcircuit) (1.8.1)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from tensorcircuit) (1.23.1)
# Collecting tensornetwork
#   Downloading tensornetwork-0.4.6-py3-none-any.whl (364 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.3/364.3 kB 34.3 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from tensornetwork->tensorcircuit) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from tensornetwork->tensorcircuit) (3.6.0)
# Requirement already satisfied: graphviz>=0.11.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from tensornetwork->tensorcircuit) (0.20.1)
# Installing collected packages: tensornetwork, tensorcircuit
# Successfully installed tensorcircuit-0.11.0 tensornetwork-0.4.6

# %%
# !pip install -U qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-0.44.1-py3-none-any.whl (8.2 kB)
# Collecting qiskit-terra==0.25.1
#   Downloading qiskit_terra-0.25.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 78.5 MB/s eta 0:00:00:00:0100:01
# Collecting ply>=3.10
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit) (2.8.2)
# Collecting symengine<0.10,>=0.9
#   Downloading symengine-0.9.2-cp310-cp310-manylinux2010_x86_64.whl (37.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 62.6 MB/s eta 0:00:0000:0100:01
# Collecting stevedore>=3.0.0
#   Downloading stevedore-5.1.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 12.7 MB/s eta 0:00:00
# Collecting rustworkx>=0.13.0
#   Downloading rustworkx-0.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 107.7 MB/s eta 0:00:00
# Requirement already satisfied: dill>=0.3 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit) (0.3.5.1)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit) (1.8.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit) (1.23.1)
# Collecting sympy>=1.3
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 136.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: typing-extensions in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit) (4.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.25.1->qiskit) (1.16.0)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 48.1 MB/s eta 0:00:00
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 45.1 MB/s eta 0:00:00
# Installing collected packages: ply, mpmath, sympy, symengine, rustworkx, pbr, stevedore, qiskit-terra, qiskit
# Successfully installed mpmath-1.3.0 pbr-5.11.1 ply-3.11 qiskit-0.44.1 qiskit-terra-0.25.1 rustworkx-0.13.1 stevedore-5.1.0 symengine-0.9.2 sympy-1.12

# %%
# !pip install -U cirq
# Out:
# Collecting cirq
#   Downloading cirq-1.2.0-py3-none-any.whl (8.1 kB)
# Collecting cirq-pasqal==1.2.0
#   Downloading cirq_pasqal-1.2.0-py3-none-any.whl (31 kB)
# Collecting cirq-ft==1.2.0
#   Downloading cirq_ft-1.2.0-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 53.1 MB/s eta 0:00:00
# Collecting cirq-ionq==1.2.0
#   Downloading cirq_ionq-1.2.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 14.9 MB/s eta 0:00:00
# Collecting cirq-aqt==1.2.0
#   Downloading cirq_aqt-1.2.0-py3-none-any.whl (27 kB)
# Collecting cirq-rigetti==1.2.0
#   Downloading cirq_rigetti-1.2.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 17.7 MB/s eta 0:00:00
# Collecting cirq-google==1.2.0
#   Downloading cirq_google-1.2.0-py3-none-any.whl (579 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 579.1/579.1 kB 43.3 MB/s eta 0:00:00
# Collecting cirq-web==1.2.0
#   Downloading cirq_web-1.2.0-py3-none-any.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.4/596.4 kB 50.6 MB/s eta 0:00:00
# Collecting cirq-core==1.2.0
#   Downloading cirq_core-1.2.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 107.5 MB/s eta 0:00:00
# Requirement already satisfied: requests~=2.18 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-aqt==1.2.0->cirq) (2.31.0)
# Requirement already satisfied: scipy in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (1.8.1)
# Requirement already satisfied: numpy~=1.16 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (1.23.1)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (1.4.3)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (2.8.4)
# Requirement already satisfied: matplotlib~=3.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (3.5.2)
# Requirement already satisfied: sortedcontainers~=2.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (2.4.0)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (4.64.0)
# Requirement already satisfied: sympy in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (1.12)
# Collecting duet~=0.2.8
#   Downloading duet-0.2.9-py3-none-any.whl (29 kB)
# Requirement already satisfied: typing-extensions>=4.2 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-core==1.2.0->cirq) (4.3.0)
# Requirement already satisfied: nbconvert in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-ft==1.2.0->cirq) (5)
# Requirement already satisfied: nbformat in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-ft==1.2.0->cirq) (5.3.0)
# Requirement already satisfied: ipywidgets in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-ft==1.2.0->cirq) (7.6.5)
# Collecting cachetools>=5.3
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: attrs in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-ft==1.2.0->cirq) (21.4.0)
# Requirement already satisfied: protobuf>=3.15.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cirq-google==1.2.0->cirq) (3.19.6)
# Collecting proto-plus>=1.20.0
#   Downloading proto_plus-1.22.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 23.0 MB/s eta 0:00:00
# Collecting google-api-core[grpc]>=1.14.0
#   Downloading google_api_core-2.12.0-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 34.7 MB/s eta 0:00:00
# Collecting pyquil~=3.2.0
#   Downloading pyquil-3.2.1-py3-none-any.whl (221 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.0/221.0 kB 41.3 MB/s eta 0:00:00
# Collecting google-auth<3.0.dev0,>=2.14.1
#   Downloading google_auth-2.23.1-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.9/181.9 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.2.0->cirq) (1.56.4)
# Collecting grpcio-status<2.0.dev0,>=1.33.2
#   Downloading grpcio_status-1.58.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.2.0->cirq) (1.42.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.2.0->cirq) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.2.0->cirq) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.2.0->cirq) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.2.0->cirq) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.2.0->cirq) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.2.0->cirq) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.2.0->cirq) (21.3)
# Collecting retry<0.10.0,>=0.9.2
#   Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Collecting lark<0.12.0,>=0.11.1
#   Downloading lark-0.11.3.tar.gz (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 54.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting qcs-api-client<0.22.0,>=0.20.13
#   Downloading qcs_api_client-0.21.6-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 27.3 MB/s eta 0:00:00
# Collecting rpcq<4.0.0,>=3.10.0
#   Downloading rpcq-3.11.0.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 19.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from requests~=2.18->cirq-aqt==1.2.0->cirq) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from requests~=2.18->cirq-aqt==1.2.0->cirq) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from requests~=2.18->cirq-aqt==1.2.0->cirq) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from requests~=2.18->cirq-aqt==1.2.0->cirq) (2.0.4)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipywidgets->cirq-ft==1.2.0->cirq) (8.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipywidgets->cirq-ft==1.2.0->cirq) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipywidgets->cirq-ft==1.2.0->cirq) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipywidgets->cirq-ft==1.2.0->cirq) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipywidgets->cirq-ft==1.2.0->cirq) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipywidgets->cirq-ft==1.2.0->cirq) (3.5.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from nbformat->cirq-ft==1.2.0->cirq) (4.4.0)
# Requirement already satisfied: fastjsonschema in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from nbformat->cirq-ft==1.2.0->cirq) (2.16.2)
# Requirement already satisfied: jupyter-core in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from nbformat->cirq-ft==1.2.0->cirq) (4.11.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from pandas->cirq-core==1.2.0->cirq) (2022.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from sympy->cirq-core==1.2.0->cirq) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]>=1.14.0->cirq-google==1.2.0->cirq) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]>=1.14.0->cirq-google==1.2.0->cirq) (0.2.8)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.5-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5.2 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from grpcio<2.0dev,>=1.33.2->google-api-core[grpc]>=1.14.0->cirq-google==1.2.0->cirq) (1.16.0)
# Collecting protobuf>=3.15.0
#   Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 36.5 MB/s eta 0:00:00
# Collecting grpcio<2.0dev,>=1.33.2
#   Downloading grpcio-1.58.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 121.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.2.0->cirq) (7.3.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.2.0->cirq) (0.1.6)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.2.0->cirq) (6.3.2)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.2.0->cirq) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.2.0->cirq) (1.5.1)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (3.0.20)
# Requirement already satisfied: backcall in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (65.6.3)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.18.1)
# Requirement already satisfied: stack-data in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.7.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->cirq-ft==1.2.0->cirq) (0.18.0)
# Collecting httpx<0.24.0,>=0.23.0
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil~=3.2.0->cirq-rigetti==1.2.0->cirq) (2.4.0)
# Collecting retrying<2.0.0,>=1.3.3
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting toml<0.11.0,>=0.10.2
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting pydantic<2.0.0,>=1.7.2
#   Downloading pydantic-1.10.13-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 81.2 MB/s eta 0:00:00:00:01
# Collecting iso8601<2.0.0,>=1.0.2
#   Downloading iso8601-1.1.0-py3-none-any.whl (9.9 kB)
# Collecting rfc3339<7.0,>=6.2
#   Downloading rfc3339-6.2-py3-none-any.whl (5.5 kB)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from retry<0.10.0,>=0.9.2->pyquil~=3.2.0->cirq-rigetti==1.2.0->cirq) (1.11.0)
# Collecting msgpack<2.0,>=0.6
#   Downloading msgpack-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (530 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.8/530.8 kB 63.1 MB/s eta 0:00:00
# Collecting python-rapidjson
#   Downloading python_rapidjson-1.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 108.4 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq>=17 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil~=3.2.0->cirq-rigetti==1.2.0->cirq) (23.2.0)
# Requirement already satisfied: ruamel.yaml in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil~=3.2.0->cirq-rigetti==1.2.0->cirq) (0.16.12)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (6.4.12)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->cirq-ft==1.2.0->cirq) (0.4)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (21.3.0)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.14.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (3.0.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.13.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]>=1.14.0->cirq-google==1.2.0->cirq) (0.4.8)
# Requirement already satisfied: pure-eval in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.2.2)
# Requirement already satisfied: executing in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (0.8.3)
# Requirement already satisfied: asttokens in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->cirq-ft==1.2.0->cirq) (2.0.5)
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 38.4 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (2.1.1)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (1.15.1)
# Requirement already satisfied: pycparser in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->cirq-ft==1.2.0->cirq) (2.21)
# Building wheels for collected packages: lark, rpcq
#   Building wheel for lark (setup.py) ... done
#   Created wheel for lark: filename=lark-0.11.3-py2.py3-none-any.whl size=99644 sha256=2c6b96ef1e25006b8799a5aa342e96bdd5e9ce4e99bf8a3c61295deba4b1b0a8
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/7d/72/22/a2dbd112cf05c55adf2e1ead5fba8aa527b848f01cdd99687c
#   Building wheel for rpcq (setup.py) ... done
#   Created wheel for rpcq: filename=rpcq-3.11.0-py3-none-any.whl size=45985 sha256=7e5c8bcf7eb7931e8c631be39de3f55b385d36e7128ecc8ad132a09491bacb58
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/91/97/0a/b384d94155345284ec00712ab814cbfb5bc2b631080b4fa4c3
# Successfully built lark rpcq
# Installing collected packages: rfc3986, rfc3339, lark, urllib3, toml, sniffio, retrying, retry, python-rapidjson, pydantic, protobuf, msgpack, iso8601, h11, grpcio, exceptiongroup, duet, cachetools, rpcq, proto-plus, google-auth, anyio, httpcore, grpcio-status, google-api-core, cirq-core, httpx, cirq-web, cirq-pasqal, cirq-ionq, cirq-aqt, qcs-api-client, cirq-google, pyquil, cirq-rigetti, cirq-ft, cirq
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.11
#     Uninstalling urllib3-1.26.11:
#       Successfully uninstalled urllib3-1.26.11
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.2
#     Uninstalling cachetools-4.2.2:
#       Successfully uninstalled cachetools-4.2.2
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.33.0
#     Uninstalling google-auth-1.33.0:
#       Successfully uninstalled google-auth-1.33.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# watson-nlp 3.6.0 requires urllib3==1.26.11, but you have urllib3 2.0.5 which is incompatible.
# watson-core 1.24.1 requires protobuf<4,>=3.19.1, but you have protobuf 4.24.3 which is incompatible.
# tensorflow 2.9.3 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.3 which is incompatible.
# tensorflow-metadata 1.8.0 requires protobuf<4,>=3.13, but you have protobuf 4.24.3 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.3 which is incompatible.
# pytorch-lightning 1.6.5 requires protobuf<=3.20.1, but you have protobuf 4.24.3 which is incompatible.
# onnx 1.12.0 requires protobuf<=3.20.1,>=3.12.2, but you have protobuf 4.24.3 which is incompatible.
# mysql-connector-python 8.0.33 requires protobuf<=3.20.3,>=3.11.0, but you have protobuf 4.24.3 which is incompatible.
# jtd-to-proto 0.6.1 requires protobuf==3.*, but you have protobuf 4.24.3 which is incompatible.
# ibm-cos-sdk-core 2.12.0 requires urllib3<1.27,>=1.26.9, but you have urllib3 2.0.5 which is incompatible.
# ibm-cloud-sdk-core 3.16.5 requires urllib3<2.0.0,>=1.26.0, but you have urllib3 2.0.5 which is incompatible.
# grpcio-tools 1.42.0 requires protobuf<4.0dev,>=3.5.0.post1, but you have protobuf 4.24.3 which is incompatible.
# botocore 1.27.28 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.0.5 which is incompatible.
# Successfully installed anyio-4.0.0 cachetools-5.3.1 cirq-1.2.0 cirq-aqt-1.2.0 cirq-core-1.2.0 cirq-ft-1.2.0 cirq-google-1.2.0 cirq-ionq-1.2.0 cirq-pasqal-1.2.0 cirq-rigetti-1.2.0 cirq-web-1.2.0 duet-0.2.9 exceptiongroup-1.1.3 google-api-core-2.12.0 google-auth-2.23.1 grpcio-1.58.0 grpcio-status-1.58.0 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 iso8601-1.1.0 lark-0.11.3 msgpack-1.0.6 proto-plus-1.22.3 protobuf-4.24.3 pydantic-1.10.13 pyquil-3.2.1 python-rapidjson-1.11 qcs-api-client-0.21.6 retry-0.9.2 retrying-1.3.4 rfc3339-6.2 rfc3986-1.5.0 rpcq-3.11.0 sniffio-1.3.0 toml-0.10.2 urllib3-2.0.5

# %%
# !pip install optax
# Out:
# Collecting optax
#   Downloading optax-0.1.7-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 27.4 MB/s eta 0:00:00
# Collecting jax>=0.1.55
#   Downloading jax-0.4.16-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.7.1 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from optax) (1.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from optax) (1.23.1)
# Collecting chex>=0.1.5
#   Downloading chex-0.1.83-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 18.9 MB/s eta 0:00:00
# Collecting jaxlib>=0.1.37
#   Downloading jaxlib-0.4.16-cp310-cp310-manylinux2014_x86_64.whl (84.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 MB 38.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from absl-py>=0.7.1->optax) (1.16.0)
# Requirement already satisfied: toolz>=0.9.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from chex>=0.1.5->optax) (0.11.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from chex>=0.1.5->optax) (4.3.0)
# Collecting numpy>=1.18.0
#   Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 95.7 MB/s eta 0:00:0000:0100:01
# Collecting ml-dtypes>=0.2.0
#   Downloading ml_dtypes-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.7/206.7 kB 65.4 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from jax>=0.1.55->optax) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages (from jax>=0.1.55->optax) (1.8.1)
# Collecting numpy>=1.18.0
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 102.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy, ml-dtypes, jaxlib, jax, chex, optax
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.1
#     Uninstalling numpy-1.23.1:
#       Successfully uninstalled numpy-1.23.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.3 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.3 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.3 which is incompatible.
# pytorch-lightning 1.6.5 requires protobuf<=3.20.1, but you have protobuf 4.24.3 which is incompatible.
# onnx 1.12.0 requires protobuf<=3.20.1,>=3.12.2, but you have protobuf 4.24.3 which is incompatible.
# numba 0.56.1 requires numpy<1.24,>=1.18, but you have numpy 1.24.4 which is incompatible.
# autoai-ts-libs 2.0.13 requires numpy<1.24,>=1.19.2; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# autoai-libs 1.14.10 requires numpy<1.24,>=1.19.2; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# Successfully installed chex-0.1.83 jax-0.4.16 jaxlib-0.4.16 ml-dtypes-0.3.1 numpy-1.24.4 optax-0.1.7

# %%
import tensorcircuit as tc
import optax
import jax.numpy as jnp
import jax
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm import tqdm

from sklearn.mixture import GaussianMixture

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# %%
plt.rcParams["font.family"] = "serif"
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['mathtext.rm'] = 'serif'
plt.rc('font', size=14)

# %%
key = jax.random.PRNGKey(42)
tf.random.set_seed(42)

# %%
dataset = 'mnist'
# dataset = 'fashion'
readout_mode = 'softmax'
# readout_mode = 'sample'
encoding_mode = 'vanilla'
# encoding_mode = 'mean'
# encoding_mode = 'half'

# %%
n = 8
n_node = 8

# %%
K = tc.set_backend('jax')

# %%
# numpy data
if dataset == 'mnist':
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
elif dataset == 'fashion':
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
ind = y_test == 9
x_test, y_test = x_test[~ind], y_test[~ind]
ind = y_test == 8
x_test, y_test = x_test[~ind], y_test[~ind]
ind = y_train == 9
x_train, y_train = x_train[~ind], y_train[~ind]
ind = y_train == 8
x_train, y_train = x_train[~ind], y_train[~ind]

x_train = x_train / 255.0
if encoding_mode == 'vanilla':
    mean = 0
elif encoding_mode == 'mean':
    mean = jnp.mean(x_train, axis=0)
elif encoding_mode == 'half':
    mean = 0.5
x_train = x_train - mean
x_train = tf.image.resize(x_train[..., tf.newaxis], (int(2**(n/2)), int(2**(n/2)))).numpy()[..., 0].reshape(-1, 2**n)
x_train = x_train / jnp.sqrt(jnp.sum(x_train**2, axis=-1, keepdims=True))

x_test = x_test / 255.0
x_test = x_test - mean
x_test = tf.image.resize(x_test[..., tf.newaxis], (int(2**(n/2)), int(2**(n/2)))).numpy()[..., 0].reshape(-1, 2**n)
x_test = x_test / jnp.sqrt(jnp.sum(x_test**2, axis=-1, keepdims=True))
y_test = jax.nn.one_hot(y_test, n_node)

def filter_pair(x, y, a, b):
    keep = (y == a) | (y == b)
    x, y = x[keep], y[keep]
    y = jax.nn.one_hot(y, n_node)
    return x, y
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 2023-09-28 12:17:56.210797: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.

# %%
def clf(params, c, k):
    for j in range(k):
        for i in range(n - 1):
            c.cnot(i, i + 1)
        for i in range(n):
            c.rx(i, theta=params[3 * j, i])
            c.rz(i, theta=params[3 * j + 1, i])
            c.rx(i, theta=params[3 * j + 2, i])
    return c

def readout(c):
    if readout_mode == 'softmax':
        logits = []
        for i in range(n_node):
            logits.append(jnp.real(c.expectation([tc.gates.z(), [i,]])))
        logits = jnp.stack(logits, axis=-1) * 10
        probs = jax.nn.softmax(logits)
    elif readout_mode == 'sample':
        wf = jnp.abs(c.wavefunction()[:n_node])**2
        probs = wf / jnp.sum(wf)
    return probs

# %%
def loss(params, x, y, k):
    c = tc.Circuit(n, inputs=x)
    c = clf(params, c, k)
    probs = readout(c)
    return -jnp.mean(jnp.sum(y * jnp.log(probs + 1e-7), axis=-1))
loss = K.jit(loss, static_argnums=[3])

# %%
def accuracy(params, x, y, k):
    c = tc.Circuit(n, inputs=x)
    c = clf(params, c, k)
    probs = readout(c)
    return jnp.argmax(probs, axis=-1) == jnp.argmax(y, axis=-1)
accuracy = K.jit(accuracy, static_argnums=[3])

# %%
k = 48

# %%
compute_loss = K.jit(K.vectorized_value_and_grad(loss, vectorized_argnums=[1, 2]), static_argnums=[3])
compute_accuracy = K.jit(K.vmap(accuracy, vectorized_argnums=[1, 2]), static_argnums=[3])

# %%
params_list = []
opt_state_list = []
data_list = []
iter_list = []
for node in tqdm(range(n_node-1)):
    x_train_node, y_train_node = filter_pair(x_train, y_train, 0, node + 1)
    data = tf.data.Dataset.from_tensor_slices((x_train_node, y_train_node)).batch(128)
    data_list.append(data)
    iter_list.append(iter(data))

    key, subkey = jax.random.split(key)
    params = jax.random.normal(subkey, (3 * k, n))
    opt = optax.adam(learning_rate=1e-2)
    opt_state = opt.init(params)
    params_list.append(params)
    opt_state_list.append(opt_state)


loss_list = []
acc_list = []
for e in tqdm(range(5), leave=False):
    for b in range(100):
        for node in range(n_node-1):
            try:
                x, y = next(iter_list[node])
            except StopIteration:
                iter_list[node] = iter(data_list[node])
                x, y = next(iter_list[node])
            x = x.numpy()
            y = y.numpy()
            loss_val, grad_val = compute_loss(params_list[node], x, y, k)
            updates, opt_state_list[node] = opt.update(grad_val, opt_state_list[node], params_list[node])
            params_list[node] = optax.apply_updates(params_list[node], updates)
        
        avg_params = jnp.mean(jnp.stack(params_list, axis=0), axis=0)
        for node in range(n_node-1):
            params_list[node] = avg_params
        
        if b % 25 == 0:
            avg_loss = jnp.mean(compute_loss(avg_params, x_test[:1024], y_test[:1024], k)[0])
            loss_list.append(avg_loss)
            acc_list.append(compute_accuracy(avg_params, x_test[:1024], y_test[:1024], k).mean())
            print(f"Epoch {e}, batch {b}/{100}, loss {avg_loss}, accuracy {acc_list[-1]}")


plt.plot(loss_list)
plt.plot(acc_list)
plt.legend(['loss', 'accuracy'])
plt.ylim(0, 1)
plt.show()
# Out:
# 100%|██████████| 7/7 [00:01<00:00,  6.09it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]2023-09-28 12:22:54.965215: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 12:34:53.820115: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 13m58.854231332s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 12:45:41.503286: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 9m43.273378627s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# Epoch 0, batch 0/100, loss 2.189169406890869, accuracy 0.1142578125
# Epoch 0, batch 25/100, loss 1.1674399375915527, accuracy 0.6689453125
# Epoch 0, batch 50/100, loss 0.9042024612426758, accuracy 0.779296875
# Epoch 0, batch 75/100, loss 0.8043765425682068, accuracy 0.8095703125
# 2023-09-28 13:02:45.068681: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 10m7.195417344s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 13:05:55.735661: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 13:18:11.335150: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 14m15.59875907s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 13:33:27.343269: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 14m11.931728781s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 13:36:32.016486: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 13:44:59.853793: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 10m27.836539211s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 13:48:06.255285: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 13:57:08.181872: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 11m1.925771858s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 14:00:14.012433: E external/xla/xla/service/slow_operation_alarm.cc:65]
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 14:08:57.472134: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 10m43.459012187s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# 2023-09-28 14:24:23.161217: E external/xla/xla/service/slow_operation_alarm.cc:133] The operation took 14m15.837835855s
#
# ********************************
# [Compiling module jit_wrapper] Very slow compile? If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
#  20%|██        | 1/5 [2:04:50<8:19:22, 7490.52s/it]
# Epoch 1, batch 0/100, loss 0.7529951333999634, accuracy 0.826171875
# Epoch 1, batch 25/100, loss 0.7293537855148315, accuracy 0.83203125
# Epoch 1, batch 50/100, loss 0.7100242376327515, accuracy 0.845703125
# Epoch 1, batch 75/100, loss 0.7142137885093689, accuracy 0.8330078125
#  40%|████      | 2/5 [2:09:50<2:43:03, 3261.06s/it]
# Epoch 2, batch 0/100, loss 0.7080438733100891, accuracy 0.8310546875
# Epoch 2, batch 25/100, loss 0.6743723750114441, accuracy 0.8505859375
# Epoch 2, batch 50/100, loss 0.6577105522155762, accuracy 0.857421875
# Epoch 2, batch 75/100, loss 0.652215838432312, accuracy 0.8623046875
#  60%|██████    | 3/5 [2:14:50<1:03:37, 1908.83s/it]
# Epoch 3, batch 0/100, loss 0.6515226364135742, accuracy 0.8681640625
# Epoch 3, batch 25/100, loss 0.6394554376602173, accuracy 0.8662109375
# Epoch 3, batch 50/100, loss 0.6202593445777893, accuracy 0.8671875
# Epoch 3, batch 75/100, loss 0.611396312713623, accuracy 0.8623046875
#  80%|████████  | 4/5 [2:19:52<21:14, 1274.40s/it]
# Epoch 4, batch 0/100, loss 0.614986777305603, accuracy 0.8740234375
# Epoch 4, batch 25/100, loss 0.6040697693824768, accuracy 0.8701171875
# Epoch 4, batch 50/100, loss 0.5960255265235901, accuracy 0.873046875
# Epoch 4, batch 75/100, loss 0.5879905223846436, accuracy 0.8720703125

# %%
mkdir mnist

# %%
jnp.save(f'./{dataset}/fedavg_loss.npy', loss_list)
jnp.save(f'./{dataset}/fedavg_acc.npy', acc_list)

# %%
def pred(params, x, k):
    c = tc.Circuit(n, inputs=x)
    c = clf(params, c, k)
    probs = readout(c)
    return probs
pred = K.vmap(pred, vectorized_argnums=[1])

# %%
jnp.mean(pred(avg_params, x_test[:1024], k).argmax(axis=-1) == y_test[:1024].argmax(axis=-1))
# Out:
# Array(0.8769531, dtype=float32)

# %%
cent_loss = jnp.load(f'./{dataset}/central_loss.npy')
cent_acc = jnp.load(f'./{dataset}/central_acc.npy')
loss_list = jnp.load(f'./{dataset}/fedavg_loss.npy')
acc_list = jnp.load(f'./{dataset}/fedavg_acc.npy')

plt.plot(jnp.arange(len(acc_list))/4, acc_list, color='blue', label='FedAvg', marker='o', markerfacecolor='none')
plt.plot(jnp.arange(len(cent_acc))/8, cent_acc, color='red', label='Centralized', marker='D', markerfacecolor='none')
# plt.hlines(0.7490, 0, 5, color='black', linestyles='dashed')
# plt.ylim(0.3, 0.8)
plt.ylabel('Top-1 accuracy')
plt.xlabel('Epochs')
plt.twinx()

plt.plot(jnp.arange(len(loss_list))/4, loss_list, color='blue', label='FedAvg', marker='o', markerfacecolor='none')
plt.plot(jnp.arange(len(cent_loss))/8, cent_loss, color='red', label='Centralized', marker='D', markerfacecolor='none')
# plt.hlines(0.1909, 0, 5, color='black', linestyles='dashed')
# plt.ylim(0.1, 0.5)
plt.ylabel('Loss')

plt.xticks(jnp.arange(6))
plt.legend(loc='center right')
plt.tight_layout()
plt.savefig(f'./{dataset}/cent_fedavg.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 cent_loss = jnp.load(f'./{dataset}/central_loss.npy')
#       2 cent_acc = jnp.load(f'./{dataset}/central_acc.npy')
#       3 loss_list = jnp.load(f'./{dataset}/fedavg_loss.npy')
#
# File /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:285, in load(*args, **kwargs)
#     281 @util._wraps(np.load, update_doc=False)
#     282 def load(*args: Any, **kwargs: Any) -> Array:
#     283   # The main purpose of this wrapper is to recover bfloat16 data types.
#     284   # Note: this will only work for files created via np.save(), not np.savez().
# --> 285   out = np.load(*args, **kwargs)
#     286   if isinstance(out, np.ndarray):
#     287     # numpy does not recognize bfloat16, so arrays are serialized as void16
#     288     if out.dtype == 'V2':
#
# File /opt/conda/envs/Python-3.10-CUDA/lib/python3.10/site-packages/numpy/lib/npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     263 @set_module('numpy')
#     264 def load(file, mmap_mode=None, allow_pickle=False, fix_imports=True,
#     265          encoding='ASCII', *, max_header_size=format._MAX_HEADER_SIZE):
#     266     """
#     267     Load arrays or pickled objects from ``.npy``, ``.npz`` or pickled files.
#     268
#    (...)
#     382
#     383     """
#     384     if encoding not in ('ASCII', 'latin1', 'bytes'):
#     385         # The 'encoding' value for pickle also affects what encoding
#     386         # the serialized binary data of NumPy arrays is loaded
#     387         # in. Pickle does not pass on the encoding information to
#     388         # NumPy. The unpickling code in numpy.core.multiarray is
#     389         # written to assume that unicode data appearing where binary
# --> 390         # should be is in 'latin1'. 'bytes' is also safe, as is 'ASCII'.
#     391         #
#     392         # Other encoding values can corrupt binary data, and we
#     393         # purposefully disallow them. For the same reason, the errors=
#     394         # argument is not exposed, as values other than 'strict'
#     395         # result can similarly silently corrupt numerical data.
#     396         raise ValueError("encoding must be 'ASCII', 'latin1', or 'bytes'")
#     398     pickle_kwargs = dict(encoding=encoding, fix_imports=fix_imports)
#
# FileNotFoundError: [Errno 2] No such file or directory: './mnist/central_loss.npy'
